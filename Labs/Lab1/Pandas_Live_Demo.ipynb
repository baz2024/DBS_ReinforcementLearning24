# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use("default")
import seaborn as sns

# %%
plt.figure()
plt.plot(np.arange(100)**2)
plt.show()

# %%
data = np.array([[2, 3, 4, 5],
                 [6, 7, 8, 9]])
data.shape
# Out:
# (2, 4)

# %%
df = pd.DataFrame(data, columns=['a', 'b', 'c', 'd'], index=['Erster_Eintrag', 'Zweiter_Eintrag'])
df
# Out:
#                  a  b  c  d
# Erster_Eintrag   2  3  4  5
# Zweiter_Eintrag  6  7  8  9

# %%
df.values
# Out:
# array([[2, 3, 4, 5],
#        [6, 7, 8, 9]])

# %%
# Komplette Spalte
df['a']
# Out:
# Erster_Eintrag     2
# Zweiter_Eintrag    6
# Name: a, dtype: int64

# %%
data[:, 0]
# Out:
# array([2, 6])

# %%
df.iloc[:, 0:3]
# Out:
#                  a  b  c
# Erster_Eintrag   2  3  4
# Zweiter_Eintrag  6  7  8

# %%
df.loc[:, ['a', 'b']]
# Out:
#                  a  b
# Erster_Eintrag   2  3
# Zweiter_Eintrag  6  7

# %%
data = np.random.randn(1000, 2)
data[:, 1] = data[:, 1]*2 + 1
df = pd.DataFrame(data, columns=['X1', 'X2'])
df.head()
# Out:
#          X1        X2
# 0 -0.492175  1.533947
# 1  1.419852 -0.242085
# 2 -0.756384 -1.068732
# 3  0.793708  3.650496
# 4  0.327739 -2.646891

# %%
plt.figure()
plt.scatter(df['X1'], df.X2)
plt.xlabel('X1')
plt.ylabel('X2')
# Out:
# Text(0, 0.5, 'X2')

# %%
sns.jointplot(x='X1', y='X2', data=df, kind='kde')

# %%
df.corr()
# Out:
#           X1        X2
# X1  1.000000  0.002316
# X2  0.002316  1.000000

# %%
df['X3'] = df['X1'] + 0.5*df['X2']

# %%
sns.jointplot(x='X1', y='X3', data=df, kind='kde')

# %%
df.corr()
# Out:
#           X1        X2        X3
# X1  1.000000  0.002316  0.686193
# X2  0.002316  1.000000  0.729007
# X3  0.686193  0.729007  1.000000

# %%
df.head()
# Out:
#          X1        X2        X3
# 0 -0.492175  1.533947  0.274798
# 1  1.419852 -0.242085  1.298810
# 2 -0.756384 -1.068732 -1.290750
# 3  0.793708  3.650496  2.618956
# 4  0.327739 -2.646891 -0.995706

# %%
for column in df.columns:
    my_column = df[column]
    print(f'{column}: Summe {np.mean(my_column)}')
# Out:
# X1: Summe -0.07717482732956077
# X2: Summe 0.9090613545096193
# X3: Summe 0.37735584992524857

# %%
df.mean(axis=0)
# Out:
# X1   -0.077175
# X2    0.909061
# X3    0.377356
# dtype: float64

# %%
 df.mean(axis=1)
# Out:
# 0      0.438857
# 1      0.825526
# 2     -1.038622
# 3      2.354386
# 4     -1.104953
#          ...
# 995   -1.847666
# 996   -1.588165
# 997    0.632345
# 998    0.087355
# 999    0.495024
# Length: 1000, dtype: float64
